# %% [markdown]
# Transformer and torch are already installed in colab environment

# %%
# !pip install transformers torch
# Out:
# Collecting transformers
#   Downloading transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: torch in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (2.5.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from transformers) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from transformers) (6.0.2)
# Collecting regex>=2025.10.22 (from transformers)
#   Using cached regex-2026.2.28-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\anshu\appdata\roaming\python\python312\site-packages (from transformers) (0.16.0)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\users\anshu\appdata\roaming\python\python312\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\anshu\appdata\roaming\python\python312\site-packages (from torch) (2025.5.1)
# Requirement already satisfied: setuptools in c:\users\anshu\appdata\roaming\python\python312\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.25.0)
# Requirement already satisfied: colorama in c:\users\anshu\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from typer->transformers) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from typer->transformers) (14.0.0)
# Requirement already satisfied: certifi in c:\users\anshu\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.8.30)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.18.0)
# Requirement already satisfied: idna in c:\users\anshu\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.10)
# Requirement already satisfied: sniffio in c:\users\anshu\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer->transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer->transformers) (2.19.2)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from httpcore<0.19.0,>=0.18.0->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anshu\miniconda3\envs\ml-zoomcamp\lib\site-packages (from httpcore<0.19.0,>=0.18.0->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anshu\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# Downloading transformers-5.4.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.1 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/10.1 MB 2.7 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/10.1 MB 2.9 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.1 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/10.1 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/10.1 MB 2.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/10.1 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/10.1 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.5/10.1 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.2/10.1 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.0/10.1 MB 2.6 MB/s eta 0:00:02
#    ------------------------- -------------- 6.6/10.1 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/10.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.1 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.1 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.1 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 2.8 MB/s eta 0:00:00
# Using cached regex-2026.2.28-cp312-cp312-win_amd64.whl (277 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: safetensors, regex, transformers
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
# Successfully installed regex-2026.2.28 safetensors-0.7.0 transformers-5.4.0
# WARNING: Ignoring invalid distribution ~lflow-skinny (C:\Users\anshu\miniconda3\envs\ml-zoomcamp\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (C:\Users\anshu\miniconda3\envs\ml-zoomcamp\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lflow-skinny (C:\Users\anshu\miniconda3\envs\ml-zoomcamp\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# prefect 3.4.8 requires httpcore<2.0.0,>=1.0.5, but you have httpcore 0.18.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline

# %%
# Load a pre-trained sentiment analysis pipeline
classifier = pipeline('sentiment-analysis')

# Sample text
text = "I love using BERT for natural language processing tasks!"

# Get prediction
result = classifier(text)
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9989564418792725}]

# %%
# Load a pre-trained NER pipeline
ner = pipeline('ner', model='dbmdz/bert-large-cased-finetuned-conll03-english')

# Sample text
text = "India lay down the gauntlet to Australia with 295-run thrashing"

# Get named entities
entities = ner(text)
for entity in entities:
    print(entity)
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'entity': 'I-LOC', 'score': 0.99978846, 'index': 1, 'word': 'India', 'start': 0, 'end': 5}
# {'entity': 'I-LOC', 'score': 0.99982905, 'index': 9, 'word': 'Australia', 'start': 31, 'end': 40}

# %%
# Load a pre-trained question-answering pipeline
qa = pipeline('question-answering',device="cuda")

# Sample context and question
context = "India won the first test against Australia"
question = "Who deafeated Australia in first test?"

# Get the answer
answer = qa({'context': context, 'question': question})
print(answer)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.5933823585510254, 'start': 0, 'end': 42, 'answer': 'India won the first test against Australia'}
